# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/My Drive/MLGT/PA1
# Out:
# /content/gdrive/My Drive/MLGT/PA1

# %% [markdown]
# **Installation**

# %%
# !pip install -e .
# !pip install cffi
# %cd /content/gdrive/My Drive/MLGT/PA1/onpolicy/envs/hanabi
# !mkdir build
# %cd build
# !cmake ..
# !make -j
# Out:
# ERROR: File "setup.py" or "setup.cfg" not found. Directory cannot be installed in editable mode: /content/gdrive/MyDrive/MLGT/PA1/onpolicy/scripts
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# /content/gdrive/My Drive/MLGT/PA1/onpolicy/envs/hanabi
# mkdir: cannot create directory ‘build’: File exists
# /content/gdrive/My Drive/MLGT/PA1/onpolicy/envs/hanabi/build
# CMake Deprecation Warning at CMakeLists.txt:1 (cmake_minimum_required):
#   Compatibility with CMake < 2.8.12 will be removed from a future version of
#   CMake.
#
#   Update the VERSION argument <min> value or use a ...<max> suffix to tell
#   CMake that the project does not need compatibility with older versions.
#
#
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /content/gdrive/My Drive/MLGT/PA1/onpolicy/envs/hanabi/build
# Consolidate compiler generated dependencies of target hanabi
# [ 66%] Built target hanabi
# ...

# %%
# %cd /content/gdrive/My Drive/MLGT/PA1/onpolicy/scripts
# !pip install wandb
# !pip install tensorboardX
# Out:
# /content/gdrive/My Drive/MLGT/PA1/onpolicy/scripts
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# **Running Hanabi**

# %%
# default
# !python3 train/train_hanabi_forward.py --env_name "Hanabi" --algorithm_name "mappo" --experiment_name "exp2" --hanabi_name "Hanabi-Very-Small"\
#               --num_agents 2 --seed 4 --n_training_threads 1 --n_rollout_threads 1 --n_eval_rollout_threads 32 --num_mini_batch 1 --episode_length 100 --num_env_steps 30001\
#                     --ppo_epoch 15 --gain 0.01 --lr 7e-4 --critic_lr 1e-3 --hidden_size 512 --layer_N 2 --use_eval --user_name "leethink"

# %%
# !python3 train/train_hanabi_forward.py --env_name "Hanabi" --algorithm_name "mappo" --experiment_name "exp1" --hanabi_name "Hanabi-Very-Small"\
              --num_agents 2 --seed 4 --n_training_threads 1 --n_rollout_threads 1 --n_eval_rollout_threads 32 --num_mini_batch 1 --episode_length 100 --num_env_steps 75001\
                    --ppo_epoch 15 --gain 0.01 --lr 7e-4 --critic_lr 1e-3 --hidden_size 256 --layer_N 2 --use_eval --user_name "leethink"
# Out:
# choose to use gpu...
# wandb: Currently logged in as: leethink. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.13.3
# wandb: Run data is saved locally in /content/gdrive/My Drive/MLGT/PA1/onpolicy/scripts/results/Hanabi/Hanabi-Very-Small/mappo/exp1/wandb/run-20221004_191826-lssl0arh
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run mappo_exp1_seed4
# wandb: ⭐️ View project at https://wandb.ai/leethink/Hanabi
# wandb: 🚀 View run at https://wandb.ai/leethink/Hanabi/runs/lssl0arh
# eval average score is 0.0.
#
#  Env Hanabi-Very-Small Algo mappo Exp exp1 updates 5/750 episodes, total num timesteps 600/75001, FPS 79.
#
# average score is 0.07142857142857142.
#
#  Env Hanabi-Very-Small Algo mappo Exp exp1 updates 10/750 episodes, total num timesteps 1100/75001, FPS 81.
#
# average score is 0.10810810810810811.
#
#  Env Hanabi-Very-Small Algo mappo Exp exp1 updates 15/750 episodes, total num timesteps 1600/75001, FPS 81.
#
# ...

# %%
# !python3 train/train_hanabi_forward.py --env_name "Hanabi" --algorithm_name "mappo" --experiment_name "exp2" --hanabi_name "Hanabi-Very-Small"\
              --num_agents 2 --seed 4 --n_training_threads 1 --n_rollout_threads 1 --n_eval_rollout_threads 32 --num_mini_batch 1 --episode_length 100 --num_env_steps 75001\
                    --ppo_epoch 15 --gain 0.01 --lr 7e-4 --critic_lr 1e-3 --hidden_size 256 --layer_N 2 --use_eval --user_name "leethink"
# Out:
# choose to use gpu...
# wandb: Currently logged in as: leethink. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.13.3
# wandb: Run data is saved locally in /content/gdrive/My Drive/MLGT/PA1/onpolicy/scripts/results/Hanabi/Hanabi-Very-Small/mappo/exp2/wandb/run-20221004_193752-2pecdf59
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run mappo_exp2_seed4
# wandb: ⭐️ View project at https://wandb.ai/leethink/Hanabi
# wandb: 🚀 View run at https://wandb.ai/leethink/Hanabi/runs/2pecdf59
# eval average score is 0.0.
#
#  Env Hanabi-Very-Small Algo mappo Exp exp2 updates 5/750 episodes, total num timesteps 600/75001, FPS 74.
#
# average score is 0.09523809523809523.
#
#  Env Hanabi-Very-Small Algo mappo Exp exp2 updates 10/750 episodes, total num timesteps 1100/75001, FPS 75.
#
# average score is 0.16129032258064516.
#
#  Env Hanabi-Very-Small Algo mappo Exp exp2 updates 15/750 episodes, total num timesteps 1600/75001, FPS 76.
#
# ...
